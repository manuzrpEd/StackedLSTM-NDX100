# %% [markdown]
# In this exercise, we will work with the NDX100 index.
# We will use a combination of AI calculations to forecast the index future price with LSTM.
#
# Citations:
#
# [1] https://www.analyticsvidhya.com/blog/2021/05/stock-price-prediction-and-forecasting-using-stacked-lstm/
#
# [2] https://github.com/devnson/Stock-Price-Prediction-StackedLSTM/blob/main/StockMarketPredictionForecasting.ipynb
#
# [3] https://saifgazali.medium.com/tesla-stock-price-prediction-using-stacked-lstms-ae51ee23669f

# %%
# If you'd like to install packages that are not installed by default, uncomment the last two lines of this cell and replace <package list> with a list of your packages.
# This will ensure your notebook has all the dependencies and works everywhere
# import sys
# !{sys.executable} -m pip install xgboost sklearn pandas numpy==1.21.0 daal==2021.4.0 seaborn scipy matplotlib yfinance tensorflow

# %%
# import libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import yfinance as yf
import numpy as np
from numpy import array
import math
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import tensorflow.keras as keras
keras.backend.clear_session()
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
import random
random.seed(10)
from numpy.random import seed
seed(1)
import tensorflow
tensorflow.random.set_seed(5)

# %% [markdown]
# # Loading the Data

# %%
asset = "^NDX"
data = yf.download(asset, start="2018-01-01")
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-01-02  6431.589844  6513.020020  6417.750000  6511.339844  6511.339844
# 2018-01-03  6520.029785  6579.250000  6519.259766  6575.799805  6575.799805
# 2018-01-04  6595.750000  6603.169922  6576.919922  6584.580078  6584.580078
# 2018-01-05  6613.129883  6654.979980  6605.029785  6653.290039  6653.290039
# 2018-01-08  6651.680176  6680.319824  6649.200195  6676.629883  6676.629883
#
#                 Volume
# Date
# 2018-01-02  1914930000
# 2018-01-03  2166780000
# 2018-01-04  2098890000
# 2018-01-05  2020900000
# 2018-01-08  2051430000

# %%
data.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2022-08-01  12877.040039  13084.610352  12833.160156  12940.780273
# 2022-08-02  12853.040039  13073.269531  12809.009766  12901.599609
# 2022-08-03  12983.580078  13289.190430  12974.849609  13253.259766
# 2022-08-04  13253.769531  13326.719727  13170.440430  13311.040039
# 2022-08-05  13107.450195  13286.019531  13070.360352  13207.690430
#
#                Adj Close      Volume
# Date
# 2022-08-01  12940.780273  4373610000
# 2022-08-02  12901.599609  4742630000
# 2022-08-03  13253.259766  5628590000
# 2022-08-04  13311.040039  5408540000
# 2022-08-05  13207.690430  4888110000

# %%
df1=data.reset_index()['Close']
df1.plot(title=asset)
# Out:
# <AxesSubplot:title={'center':'^NDX'}>

# %%
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))
df1
# Out:
# array([[0.05733468],
#        [0.06337365],
#        [0.06419624],
#        ...,
#        [0.68895604],
#        [0.69436922],
#        [0.68468684]])

# %%
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]
train_data.shape, test_data.shape
# Out:
# ((752, 1), (405, 1))

# %% [markdown]
# # Data Preprocessing

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(dataset.shape[0]-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((651, 100), (651,), (304, 100), (304,))

# %%
X_train
# Out:
# array([[0.05733468, 0.06337365, 0.06419624, ..., 0.09314886, 0.09877092,
#         0.09840276],
#        [0.06337365, 0.06419624, 0.07063338, ..., 0.09877092, 0.09840276,
#         0.09945389],
#        [0.06419624, 0.07063338, 0.07281999, ..., 0.09840276, 0.09945389,
#         0.09623299],
#        ...,
#        [0.4512052 , 0.46904015, 0.48301808, ..., 0.63414058, 0.64200075,
#         0.64070041],
#        [0.46904015, 0.48301808, 0.48690228, ..., 0.64200075, 0.64070041,
#         0.636211  ],
#        [0.48301808, 0.48690228, 0.48960983, ..., 0.64070041, 0.636211  ,
#         0.6387686 ]])

# %% [markdown]
# # LSTM Model

# %%
# Reshape input to be [samples, time steps, features] which is required for LSTM
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
X_train
# Out:
# array([[[0.05733468],
#         [0.06337365],
#         [0.06419624],
#         ...,
#         [0.09314886],
#         [0.09877092],
#         [0.09840276]],
#
#        [[0.06337365],
#         [0.06419624],
#         [0.07063338],
#         ...,
#         [0.09877092],
#         [0.09840276],
#         [0.09945389]],
#
#        [[0.06419624],
#         [0.07063338],
#         [0.07281999],
#         ...,
#         [0.09840276],
#         [0.09945389],
#         [0.09623299]],
#
#        ...,
#
#        [[0.4512052 ],
#         [0.46904015],
#         [0.48301808],
#         ...,
#         [0.63414058],
#         [0.64200075],
#         [0.64070041]],
#
#        [[0.46904015],
#         [0.48301808],
#         [0.48690228],
#         ...,
#         [0.64200075],
#         [0.64070041],
#         [0.636211  ]],
#
#        [[0.48301808],
#         [0.48690228],
#         [0.48960983],
#         ...,
#         [0.64070041],
#         [0.636211  ],
#         [0.6387686 ]]])

# %%
model=Sequential()
# https://keras.io/api/layers/activations/
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/LSTM 
# sigmoid by default
model.add(LSTM(50,return_sequences=True,input_shape=(time_step,1))) #, activation='tanh'
# model.add(Dropout(0.2))
model.add(LSTM(50,return_sequences=True)) #, activation='tanh'
model.add(LSTM(50))
model.add(Dense(1))
# https://keras.io/api/optimizers/
# model.compile(loss='mean_squared_error',optimizer='adam')# adaptive moment estimation GOOD
# model.compile(loss='mean_squared_error',optimizer='SGD')# Stochastic Gradient Descendent BAD
model.compile(loss='mean_squared_error',optimizer='RMSprop')# Root Mean Squared Propagation BEST
# model.compile(loss='mean_squared_error',optimizer='Adagrad')# Adaptive Gradient Algorithm VERY BAD
# model.compile(loss='mean_squared_error',optimizer='Adadelta')# adapts learning rates VERY BAD
# model.compile(loss='mean_squared_error',optimizer='Adamax')# Adam based on the infinity norm OK
# model.compile(loss='mean_squared_error',optimizer='Nadam')# Nesterov-accelerated Adaptive Moment Estimation OK
# model.compile(loss='mean_squared_error',optimizer='Ftrl')# Follow The Regularized Leader NA
# https://keras.io/api/losses/
# model.compile(loss='huber',optimizer='RMSprop')# OK
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 100, batch_size = 64, verbose = 1)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 18s 498ms/step - loss: 0.0180 - val_loss: 0.0038
# Epoch 2/100
# 11/11 [==============================] - 2s 219ms/step - loss: 0.0031 - val_loss: 0.0081
# Epoch 3/100
# 11/11 [==============================] - 3s 311ms/step - loss: 0.0042 - val_loss: 0.0252
# Epoch 4/100
# 11/11 [==============================] - 3s 294ms/step - loss: 0.0030 - val_loss: 0.0091
# Epoch 5/100
# 11/11 [==============================] - 3s 284ms/step - loss: 0.0022 - val_loss: 0.0067
# Epoch 6/100
# 11/11 [==============================] - 3s 282ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 7/100
# 11/11 [==============================] - 3s 285ms/step - loss: 0.0031 - val_loss: 0.0160
# Epoch 8/100
# 11/11 [==============================] - 3s 277ms/step - loss: 0.0024 - val_loss: 0.0069
# Epoch 9/100
# 11/11 [==============================] - 3s 278ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 10/100
# 11/11 [==============================] - 3s 285ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 11/100
# 11/11 [==============================] - 3s 275ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 12/100
# 11/11 [==============================] - 3s 278ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 13/100
# 11/11 [==============================] - 3s 277ms/step - loss: 0.0020 - val_loss: 0.0051
# Epoch 14/100
# 11/11 [==============================] - 3s 291ms/step - loss: 0.0014 - val_loss: 0.0084
# Epoch 15/100
# 11/11 [==============================] - 3s 280ms/step - loss: 0.0019 - val_loss: 0.0046
# Epoch 16/100
# 11/11 [==============================] - 3s 277ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 17/100
# 11/11 [==============================] - 3s 284ms/step - loss: 0.0018 - val_loss: 0.0052
# Epoch 18/100
# 11/11 [==============================] - 3s 287ms/step - loss: 0.0014 - val_loss: 0.0066
# Epoch 19/100
# 11/11 [==============================] - 3s 278ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 20/100
# 11/11 [==============================] - 3s 278ms/step - loss: 0.0011 - val_loss: 0.0045
# Epoch 21/100
# 11/11 [==============================] - 3s 289ms/step - loss: 0.0013 - val_loss: 0.0081
# Epoch 22/100
# 11/11 [==============================] - 3s 273ms/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 23/100
# 11/11 [==============================] - 3s 287ms/step - loss: 5.9524e-04 - val_loss: 0.0576
# Epoch 24/100
# 11/11 [==============================] - 3s 279ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 25/100
# 11/11 [==============================] - 3s 295ms/step - loss: 0.0011 - val_loss: 0.0033
# Epoch 26/100
# 11/11 [==============================] - 3s 276ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 27/100
# 11/11 [==============================] - 3s 286ms/step - loss: 0.0010 - val_loss: 0.0049
# Epoch 28/100
# 11/11 [==============================] - 3s 282ms/step - loss: 0.0011 - val_loss: 0.0260
# Epoch 29/100
# 11/11 [==============================] - 3s 278ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 30/100
# 11/11 [==============================] - 3s 295ms/step - loss: 5.1835e-04 - val_loss: 0.0118
# Epoch 31/100
# 11/11 [==============================] - 3s 293ms/step - loss: 0.0013 - val_loss: 0.0253
# Epoch 32/100
# 11/11 [==============================] - 3s 292ms/step - loss: 0.0013 - val_loss: 0.0050
# Epoch 33/100
# 11/11 [==============================] - 3s 272ms/step - loss: 9.4045e-04 - val_loss: 0.0015
# Epoch 34/100
# 11/11 [==============================] - 3s 282ms/step - loss: 5.3305e-04 - val_loss: 0.0192
# Epoch 35/100
# 11/11 [==============================] - 3s 281ms/step - loss: 9.6802e-04 - val_loss: 0.0065
# Epoch 36/100
# 11/11 [==============================] - 3s 284ms/step - loss: 8.1924e-04 - val_loss: 0.0026
# Epoch 37/100
# 11/11 [==============================] - 3s 289ms/step - loss: 9.6307e-04 - val_loss: 0.0039
# Epoch 38/100
# 11/11 [==============================] - 3s 280ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 39/100
# 11/11 [==============================] - 3s 283ms/step - loss: 5.9969e-04 - val_loss: 0.0316
# Epoch 40/100
# 11/11 [==============================] - 3s 280ms/step - loss: 9.0918e-04 - val_loss: 0.0131
# Epoch 41/100
# 11/11 [==============================] - 3s 282ms/step - loss: 7.4248e-04 - val_loss: 0.0013
# Epoch 42/100
# 11/11 [==============================] - 3s 280ms/step - loss: 0.0011 - val_loss: 0.0085
# Epoch 43/100
# 11/11 [==============================] - 3s 293ms/step - loss: 8.9516e-04 - val_loss: 0.0052
# Epoch 44/100
# 11/11 [==============================] - 3s 279ms/step - loss: 7.0921e-04 - val_loss: 0.0013
# Epoch 45/100
# 11/11 [==============================] - 3s 282ms/step - loss: 7.9061e-04 - val_loss: 0.0011
# Epoch 46/100
# 11/11 [==============================] - 3s 280ms/step - loss: 0.0010 - val_loss: 0.0031
# Epoch 47/100
# 11/11 [==============================] - 3s 283ms/step - loss: 4.4666e-04 - val_loss: 0.0198
# Epoch 48/100
# 11/11 [==============================] - 3s 281ms/step - loss: 9.0232e-04 - val_loss: 0.0176
# Epoch 49/100
# 11/11 [==============================] - 3s 278ms/step - loss: 8.1887e-04 - val_loss: 0.0013
# Epoch 50/100
# 11/11 [==============================] - 3s 295ms/step - loss: 7.0952e-04 - val_loss: 0.0066
# Epoch 51/100
# 11/11 [==============================] - 3s 280ms/step - loss: 7.5820e-04 - val_loss: 0.0020
# Epoch 52/100
# 11/11 [==============================] - 3s 283ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 53/100
# 11/11 [==============================] - 3s 288ms/step - loss: 3.5597e-04 - val_loss: 0.0148
# Epoch 54/100
# 11/11 [==============================] - 3s 282ms/step - loss: 7.1935e-04 - val_loss: 0.0139
# Epoch 55/100
# 11/11 [==============================] - 3s 280ms/step - loss: 6.6630e-04 - val_loss: 0.0017
# Epoch 56/100
# 11/11 [==============================] - 3s 286ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 57/100
# 11/11 [==============================] - 3s 280ms/step - loss: 5.3595e-04 - val_loss: 0.0046
# Epoch 58/100
# 11/11 [==============================] - 3s 279ms/step - loss: 7.2353e-04 - val_loss: 0.0141
# Epoch 59/100
# 11/11 [==============================] - 3s 287ms/step - loss: 7.4201e-04 - val_loss: 0.0012
# Epoch 60/100
# 11/11 [==============================] - 3s 281ms/step - loss: 7.1077e-04 - val_loss: 0.0013
# Epoch 61/100
# 11/11 [==============================] - 3s 280ms/step - loss: 5.1272e-04 - val_loss: 0.0051
# Epoch 62/100
# 11/11 [==============================] - 3s 281ms/step - loss: 4.6004e-04 - val_loss: 0.0011
# Epoch 63/100
# 11/11 [==============================] - 3s 283ms/step - loss: 5.3837e-04 - val_loss: 0.0013
# Epoch 64/100
# 11/11 [==============================] - 3s 300ms/step - loss: 6.8944e-04 - val_loss: 0.0073
# Epoch 65/100
# 11/11 [==============================] - 3s 273ms/step - loss: 7.1746e-04 - val_loss: 0.0021
# Epoch 66/100
# 11/11 [==============================] - 3s 279ms/step - loss: 4.5642e-04 - val_loss: 0.0011
# Epoch 67/100
# 11/11 [==============================] - 3s 284ms/step - loss: 8.4917e-04 - val_loss: 0.0031
# Epoch 68/100
# 11/11 [==============================] - 3s 291ms/step - loss: 3.1666e-04 - val_loss: 0.0052
# Epoch 69/100
# 11/11 [==============================] - 3s 281ms/step - loss: 7.6048e-04 - val_loss: 0.0042
# Epoch 70/100
# 11/11 [==============================] - 3s 281ms/step - loss: 3.5091e-04 - val_loss: 0.0053
# Epoch 71/100
# 11/11 [==============================] - 3s 286ms/step - loss: 5.9164e-04 - val_loss: 0.0017
# Epoch 72/100
# 11/11 [==============================] - 3s 277ms/step - loss: 5.0710e-04 - val_loss: 0.0021
# Epoch 73/100
# 11/11 [==============================] - 3s 282ms/step - loss: 3.4929e-04 - val_loss: 0.0010
# Epoch 74/100
# 11/11 [==============================] - 3s 286ms/step - loss: 7.3530e-04 - val_loss: 0.0032
# Epoch 75/100
# 11/11 [==============================] - 4s 335ms/step - loss: 2.7452e-04 - val_loss: 0.0012
# Epoch 76/100
# 11/11 [==============================] - 3s 246ms/step - loss: 6.5895e-04 - val_loss: 0.0090
# Epoch 77/100
# 11/11 [==============================] - 3s 329ms/step - loss: 3.6715e-04 - val_loss: 0.0254
# Epoch 78/100
# 11/11 [==============================] - 2s 185ms/step - loss: 4.8168e-04 - val_loss: 0.0029
# Epoch 79/100
# 11/11 [==============================] - 2s 205ms/step - loss: 4.5297e-04 - val_loss: 0.0062
# Epoch 80/100
# 11/11 [==============================] - 3s 302ms/step - loss: 5.8458e-04 - val_loss: 0.0061
# Epoch 81/100
# 11/11 [==============================] - 2s 229ms/step - loss: 6.5040e-04 - val_loss: 0.0041
# Epoch 82/100
# 11/11 [==============================] - 3s 304ms/step - loss: 2.2386e-04 - val_loss: 0.0016
# Epoch 83/100
# 11/11 [==============================] - 2s 225ms/step - loss: 5.2708e-04 - val_loss: 0.0053
# Epoch 84/100
# 11/11 [==============================] - 3s 246ms/step - loss: 6.0951e-04 - val_loss: 0.0030
# Epoch 85/100
# 11/11 [==============================] - 3s 256ms/step - loss: 3.8918e-04 - val_loss: 0.0063
# Epoch 86/100
# 11/11 [==============================] - 3s 278ms/step - loss: 4.8951e-04 - val_loss: 0.0011
# Epoch 87/100
# 11/11 [==============================] - 3s 237ms/step - loss: 5.9216e-04 - val_loss: 0.0075
# Epoch 88/100
# 11/11 [==============================] - 3s 281ms/step - loss: 3.1855e-04 - val_loss: 0.0047
# Epoch 89/100
# 11/11 [==============================] - 2s 225ms/step - loss: 5.3254e-04 - val_loss: 0.0018
# Epoch 90/100
# 11/11 [==============================] - 3s 250ms/step - loss: 3.7903e-04 - val_loss: 0.0028
# Epoch 91/100
# 11/11 [==============================] - 3s 302ms/step - loss: 5.4394e-04 - val_loss: 9.4280e-04
# Epoch 92/100
# 11/11 [==============================] - 2s 204ms/step - loss: 3.3557e-04 - val_loss: 0.0011
# Epoch 93/100
# 11/11 [==============================] - 3s 276ms/step - loss: 5.4342e-04 - val_loss: 0.0090
# Epoch 94/100
# 11/11 [==============================] - 3s 319ms/step - loss: 4.7932e-04 - val_loss: 0.0054
# Epoch 95/100
# 11/11 [==============================] - 2s 189ms/step - loss: 4.5874e-04 - val_loss: 0.0012
# Epoch 96/100
# 11/11 [==============================] - 2s 210ms/step - loss: 4.8095e-04 - val_loss: 0.0063
# Epoch 97/100
# 11/11 [==============================] - 3s 274ms/step - loss: 4.5181e-04 - val_loss: 0.0046
# Epoch 98/100
# 11/11 [==============================] - 3s 258ms/step - loss: 4.1250e-04 - val_loss: 0.0013
# Epoch 99/100
# 11/11 [==============================] - 3s 274ms/step - loss: 5.1067e-04 - val_loss: 0.0012
# Epoch 100/100
# 11/11 [==============================] - 3s 269ms/step - loss: 3.2879e-04 - val_loss: 0.0012

# %%
y_train=scaler.inverse_transform(np.array(y_train).reshape(-1,1))
y_test=scaler.inverse_transform(np.array(y_test).reshape(-1,1))

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)
# Out:
# 21/21 [==============================] - 2s 27ms/step
# 10/10 [==============================] - 0s 27ms/step

# %%
plt.figure(figsize=(26,12))
plt.plot(train_predict,color='red',label='Prediction')
plt.plot(y_train,color='blue',label='Data')
# plt.gca().xaxis.set_major_locator(years)
plt.xlabel('Days')
plt.title(asset+" Training")
plt.legend(loc='best')
plt.show()

# %%
round(math.sqrt(mean_squared_error(y_train,train_predict)),2)
# Out:
# 230.16

# %%
plt.figure(figsize=(26,12))
plt.plot(test_predict,color='red',label='Prediction')
plt.plot(y_test,color='blue',label='Data')
# plt.gca().xaxis.set_major_locator(years)
plt.xlabel('Days')
plt.title(asset+" Test")
plt.legend(loc='best')
plt.show()

# %%
round(math.sqrt(mean_squared_error(y_test, test_predict)),2)
# Out:
# 366.37

# %%
# Plotting
# Shift train predictionis for plotting

look_back = time_step
trainPredictPlot = np.empty_like(df1)
trainPredictPlot[:,:] = np.nan
trainPredictPlot[look_back: len(train_predict) + look_back, :] = train_predict


# Shif test prediction for plotting
testPredictPlot = np.empty_like(df1)
testPredictPlot[:,:] = np.nan
testPredictPlot[len(train_predict) + (look_back*2) + 1: len(df1)-1,:] = test_predict


# plot baseline and predictions
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.title(asset)
plt.show()

# %% [markdown]
# # Forecasting - 10 Days Ahead

# %%
len(test_data)
# Out:
# 405

# %%
X_input = test_data[len(test_data)-time_step:].reshape(1,-1)
X_input.shape
# Out:
# (1, 100)

# %%
temp_input = list(X_input)
temp_input = temp_input[0].tolist()

# %%
# Demonstrate prediction for next 10 days

lst_output = []
n_steps = time_step
i = 0
days_ahead = 10

while(i<days_ahead):
  if(len(temp_input) > time_step):
    # print(temp_input)
    X_input = np.array(temp_input[1:])
#     print(" {} day input {}".format(i, X_input))
    X_input = X_input.reshape(1,-1)
    X_input = X_input.reshape((1, n_steps, 1))

    # print(X_input)
    yhat = model.predict(X_input, verbose = 0)
#     print("{} day output {}".format(i, yhat))
    temp_input.extend(yhat[0].tolist())
    temp_input = temp_input[1:]

    # print(temp_input)
    lst_output.extend(yhat.tolist())
    i = i+1
  else:
    X_input = X_input.reshape((1, n_steps, 1))
    yhat = model.predict(X_input, verbose = 0)
#     print(yhat[0])
    temp_input.extend(yhat[0].tolist())
#     print(len(temp_input))
    lst_output.extend(yhat.tolist())
    i = i+1

# print(lst_output)

# %%
day_new = np.arange(1,time_step+1)
day_pred = np.arange(time_step+1, time_step+1+days_ahead)

# %%
len(df1)
# Out:
# 1157

# %%
plt.plot(day_new, scaler.inverse_transform(df1[len(df1)-time_step:]))
plt.plot(day_pred, scaler.inverse_transform(lst_output))
plt.show()
